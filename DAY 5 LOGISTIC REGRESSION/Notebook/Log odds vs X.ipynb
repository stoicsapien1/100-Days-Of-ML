# %%
import seaborn as sns
import pandas as pd
df=sns.load_dataset("titanic")

# %%
df=df.dropna()

# %%
num=df.select_dtypes(include=["int64","float64"])

# %%
sns.heatmap(num.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
X=df[["age","fare"]].dropna()
y=df["survived"].dropna()

# %%
X
# Out:
#       age     fare
# 1    38.0  71.2833
# 3    35.0  53.1000
# 6    54.0  51.8625
# 10    4.0  16.7000
# 11   58.0  26.5500
# ..    ...      ...
# 871  47.0  52.5542
# 872  33.0   5.0000
# 879  56.0  83.1583
# 887  19.0  30.0000
# 889  26.0  30.0000
#
# [182 rows x 2 columns]

# %%
y
# Out:
# 1      1
# 3      1
# 6      0
# 10     1
# 11     1
#       ..
# 871    1
# 872    0
# 879    1
# 887    1
# 889    1
# Name: survived, Length: 182, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
predicted =model.predict_proba(X)[:,1]

# %%
predicted.shape
# Out:
# (182,)

# %%
import numpy as np
log_odds=np.log(predicted/(1-predicted))

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df["fare"],y=log_odds)

# %%
plt.scatter(x=df["age"],y=log_odds)
