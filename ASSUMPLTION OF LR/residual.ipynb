# %%
from sklearn.datasets import make_regression
import pandas as pd

# Create a synthetic regression dataset
X, y = make_regression(n_samples=1000,        # Number of samples
                       n_features=10,         # Number of features
                       n_informative=8,       # Number of informative features
                       noise=0.2,             # Amount of noise in the data
                       random_state=42)       # For reproducibility

# Convert to a DataFrame
df = pd.DataFrame(X, columns=[f'Feature_{i}' for i in range(1, 11)])
df['Target'] = y

# Display the first few rows
print(df.head())
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0  -0.707669   2.122156  -1.260884   0.917862   0.774634  -1.519370
# 1   0.668655  -0.730956  -0.535335   0.358454   1.295872   0.685508
# 2   0.691619  -0.624510  -1.045529  -0.026261  -0.998212   0.031492
# 3   0.146476  -1.167865  -0.111847  -0.452690  -0.800590   1.107721
# 4  -2.205566  -0.635362  -1.876553   0.619711   1.274875  -0.624345
#
#    Feature_7  Feature_8  Feature_9  Feature_10      Target
# 0   1.266911   1.032465  -0.484234    0.443819 -107.566413
# 1  -0.175564   0.757922   1.848609    0.098068   82.660626
# 2   1.087710   0.746981   0.690074    0.273118   62.847774
# 3   0.644311  -0.328375   0.566602    0.523324   80.692029
# 4  -0.604745  -1.189667  -0.184525    0.897066 -293.607530

# %%
df
# Out:
#      Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0    -0.707669   2.122156  -1.260884   0.917862   0.774634  -1.519370
# 1     0.668655  -0.730956  -0.535335   0.358454   1.295872   0.685508
# 2     0.691619  -0.624510  -1.045529  -0.026261  -0.998212   0.031492
# 3     0.146476  -1.167865  -0.111847  -0.452690  -0.800590   1.107721
# 4    -2.205566  -0.635362  -1.876553   0.619711   1.274875  -0.624345
# ..         ...        ...        ...        ...        ...        ...
# 995   0.428186  -0.596974   0.379153   1.230222  -1.279031  -0.412221
# 996   1.647878   0.562854  -1.088693   0.561473   0.126313   0.780202
# 997  -1.506534   2.492184   0.249451   0.399228  -0.587115  -0.317761
# 998  -0.251539   1.194109  -1.725807  -0.677565   1.422370  -0.464404
# 999   0.298798   0.058370  -0.025494  -0.217159   1.898735  -0.343206
#
#      Feature_7  Feature_8  Feature_9  Feature_10      Target
# 0     1.266911   1.032465  -0.484234    0.443819 -107.566413
# ...

# %%
import seaborn as sns
sns.scatterplot(data=df,x="Feature_1",y="Target")
# Out:
# <Axes: xlabel='Feature_1', ylabel='Target'>

# %%
df
# Out:
#      Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0    -0.707669   2.122156  -1.260884   0.917862   0.774634  -1.519370
# 1     0.668655  -0.730956  -0.535335   0.358454   1.295872   0.685508
# 2     0.691619  -0.624510  -1.045529  -0.026261  -0.998212   0.031492
# 3     0.146476  -1.167865  -0.111847  -0.452690  -0.800590   1.107721
# 4    -2.205566  -0.635362  -1.876553   0.619711   1.274875  -0.624345
# ..         ...        ...        ...        ...        ...        ...
# 995   0.428186  -0.596974   0.379153   1.230222  -1.279031  -0.412221
# 996   1.647878   0.562854  -1.088693   0.561473   0.126313   0.780202
# 997  -1.506534   2.492184   0.249451   0.399228  -0.587115  -0.317761
# 998  -0.251539   1.194109  -1.725807  -0.677565   1.422370  -0.464404
# 999   0.298798   0.058370  -0.025494  -0.217159   1.898735  -0.343206
#
#      Feature_7  Feature_8  Feature_9  Feature_10      Target
# 0     1.266911   1.032465  -0.484234    0.443819 -107.566413
# ...

# %%
y=df["Target"]

# %%
X=df.iloc[:,:-1]

# %%
X
# Out:
#      Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0    -0.707669   2.122156  -1.260884   0.917862   0.774634  -1.519370
# 1     0.668655  -0.730956  -0.535335   0.358454   1.295872   0.685508
# 2     0.691619  -0.624510  -1.045529  -0.026261  -0.998212   0.031492
# 3     0.146476  -1.167865  -0.111847  -0.452690  -0.800590   1.107721
# 4    -2.205566  -0.635362  -1.876553   0.619711   1.274875  -0.624345
# ..         ...        ...        ...        ...        ...        ...
# 995   0.428186  -0.596974   0.379153   1.230222  -1.279031  -0.412221
# 996   1.647878   0.562854  -1.088693   0.561473   0.126313   0.780202
# 997  -1.506534   2.492184   0.249451   0.399228  -0.587115  -0.317761
# 998  -0.251539   1.194109  -1.725807  -0.677565   1.422370  -0.464404
# 999   0.298798   0.058370  -0.025494  -0.217159   1.898735  -0.343206
#
#      Feature_7  Feature_8  Feature_9  Feature_10
# 0     1.266911   1.032465  -0.484234    0.443819
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X)

# %%
residual=y-y_pred

# %%
residual
# Out:
# 0      0.162603
# 1      0.325030
# 2      0.023150
# 3      0.228038
# 4     -0.083327
#          ...
# 995    0.026110
# 996    0.029542
# 997    0.250106
# 998   -0.265215
# 999   -0.010806
# Name: Target, Length: 1000, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(y_pred,residual)

# %%
residual
# Out:
# 0      0.162603
# 1      0.325030
# 2      0.023150
# 3      0.228038
# 4     -0.083327
#          ...
# 995    0.026110
# 996    0.029542
# 997    0.250106
# 998   -0.265215
# 999   -0.010806
# Name: Target, Length: 1000, dtype: float64

# %%
data={"residual":residual}

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#      residual
# 0    0.162603
# 1    0.325030
# 2    0.023150
# 3    0.228038
# 4   -0.083327
# ..        ...
# 995  0.026110
# 996  0.029542
# 997  0.250106
# 998 -0.265215
# 999 -0.010806
#
# [1000 rows x 1 columns]

# %%
sns.histplot(df1["residual"],kde=True)
# Out:
# <Axes: xlabel='residual', ylabel='Count'>

# %%
## QQ plot of the residual to check normality assumption.
from scipy import stats

plt.figure(figsize=(8,6))
stats.probplot(df1["residual"],plot=plt)
plt.show()

# %%
df1.describe()
# Out:
#            residual
# count  1.000000e+03
# mean   1.089129e-16
# std    1.921929e-01
# min   -6.249629e-01
# 25%   -1.285583e-01
# 50%    2.135337e-03
# 75%    1.301707e-01
# max    5.909322e-01
