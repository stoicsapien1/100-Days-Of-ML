# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
import seaborn as sns

# %%
X=np.random.rand(100,1)-0.5
y=3*X[:,0]**2+0.05*np.random.randn(100)

# %%
# Out:
# array([-0.64657288, -1.081548  ,  1.68714164,  0.88163976, -0.00797264,
#         1.47994414,  0.07736831, -0.8612842 ,  1.52312408,  0.53891004,
#        -1.03724615, -0.19033868, -0.87561825, -1.38279973,  0.92617755,
#         1.90941664, -1.39856757,  0.56296924, -0.65064257, -0.48712538,
#        -0.59239392, -0.86399077,  0.04852163, -0.83095012,  0.27045683,
#        -0.05023811, -0.23894805, -0.90756366, -0.57677133,  0.75539123,
#         0.50091719, -0.97755524,  0.09933231,  0.75138712, -1.66940528,
#         0.54336019, -0.66262376,  0.57059867, -0.76325916, -1.8048821 ,
#        -1.62754244,  0.04808495,  0.2597225 , -0.90431663,  0.63859246,
#        -1.66152006, -0.0660798 , -1.2110162 , -0.65183611,  0.04739867,
#        -0.86041337, -0.38455554,  1.00629281, -0.57689187,  0.83569211,
#        -1.12970685,  0.52980418,  1.44156862, -2.4716445 , -0.79689526,
#         0.57707213, -0.20304539,  0.37114587, -0.60398519,  0.08658979,
# ...

# %%
X
# Out:
# array([[-0.39687613],
#        [ 0.40255291],
#        [ 0.00525237],
#        [ 0.32645747],
#        [-0.1799504 ],
#        [ 0.39552323],
#        [-0.11079832],
#        [-0.48916235],
#        [ 0.40538198],
#        [-0.40871332],
#        [-0.18068636],
#        [ 0.45006197],
#        [ 0.45060715],
#        [ 0.07343789],
#        [ 0.13183721],
#        [-0.05155448],
#        [-0.20678923],
#        [-0.17133545],
#        [ 0.17251846],
#        [ 0.25237453],
#        [ 0.29157904],
#        [ 0.28961814],
#        [-0.4087939 ],
#        [-0.0055797 ],
#        [-0.44244124],
#        [ 0.04952888],
#        [-0.0584695 ],
#        [ 0.38770418],
#        [-0.14908499],
#        [-0.38293298],
#        [-0.35700832],
#        [ 0.26151063],
#        [ 0.11821806],
#        [-0.39887732],
#        [-0.41589319],
#        [ 0.20096913],
#        [-0.42723699],
#        [ 0.32186006],
#        [ 0.20624223],
#        [-0.41865122],
#        [-0.41516229],
# ...

# %%
import pandas as pd
df=pd.DataFrame()
df["X"]=X.reshape(100)
df["y"]=y

# %%
df
# Out:
#            X         y
# 0  -0.396876  0.489620
# 1   0.402553  0.579955
# 2   0.005252  0.047604
# 3   0.326457  0.290878
# 4  -0.179950  0.052226
# ..       ...       ...
# 95 -0.146648  0.016740
# 96  0.083656 -0.059327
# 97 -0.422265  0.545097
# 98  0.474395  0.637334
# 99  0.486211  0.638090
#
# [100 rows x 2 columns]

# %%
plt.scatter(df["X"],df["y"])

# %%
df["pred1"]=df["y"].mean()

# %%
df
# Out:
#            X         y     pred1
# 0  -0.396876  0.489620  0.301479
# 1   0.402553  0.579955  0.301479
# 2   0.005252  0.047604  0.301479
# 3   0.326457  0.290878  0.301479
# 4  -0.179950  0.052226  0.301479
# ..       ...       ...       ...
# 95 -0.146648  0.016740  0.301479
# 96  0.083656 -0.059327  0.301479
# 97 -0.422265  0.545097  0.301479
# 98  0.474395  0.637334  0.301479
# 99  0.486211  0.638090  0.301479
#
# [100 rows x 3 columns]

# %%
df["res1"]=df["y"]-df["pred1"]

# %%
plt.scatter(df["X"],df["y"])
plt.plot(df["X"],df["pred1"],color="red")

# %%
from sklearn.tree import DecisionTreeRegressor
tree1=DecisionTreeRegressor(max_leaf_nodes=8)

# %%
tree1.fit(df["X"].values.reshape(100,1),df["res1"].values)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=8)

# %%
from sklearn.tree import plot_tree
plot_tree(tree1)
plt.show()

# %%
sns.kdeplot(np.linspace(-0.5,0.5,500))
# Out:
# <Axes: ylabel='Density'>

# %%
X_test=np.linspace(-0.5,0.5,500)

# %%
y_pred=0.301479+tree1.predict(X_test.reshape(500,1))

# %%
y_pred
# Out:
# array([0.71033099, 0.71033099, 0.71033099, 0.71033099, 0.71033099,
#        0.71033099, 0.71033099, 0.71033099, 0.71033099, 0.71033099,
#        0.71033099, 0.71033099, 0.71033099, 0.71033099, 0.56212415,
#        0.56212415, 0.56212415, 0.56212415, 0.56212415, 0.56212415,
#        0.56212415, 0.56212415, 0.56212415, 0.56212415, 0.56212415,
#        0.56212415, 0.56212415, 0.56212415, 0.56212415, 0.56212415,
#        0.56212415, 0.56212415, 0.56212415, 0.56212415, 0.56212415,
#        0.56212415, 0.56212415, 0.56212415, 0.56212415, 0.56212415,
#        0.56212415, 0.56212415, 0.56212415, 0.45760348, 0.45760348,
#        0.45760348, 0.45760348, 0.45760348, 0.45760348, 0.45760348,
#        0.45760348, 0.45760348, 0.45760348, 0.45760348, 0.45760348,
#        0.45760348, 0.45760348, 0.45760348, 0.45760348, 0.45760348,
#        0.45760348, 0.45760348, 0.45760348, 0.45760348, 0.45760348,
#        0.45760348, 0.45760348, 0.45760348, 0.45760348, 0.45760348,
# ...

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.plot(X_test,y_pred,linewidth=2,color="red")
plt.scatter(df["X"],df["y"])

# %%
df["pred2"]=0.301479+tree1.predict(df["X"].values.reshape(100,1))

# %%
df
# Out:
#            X         y     pred1      res1     pred2
# 0  -0.396876  0.489620  0.301479  0.188140  0.457603
# 1   0.402553  0.579955  0.301479  0.278476  0.477543
# 2   0.005252  0.047604  0.301479 -0.253875  0.025367
# 3   0.326457  0.290878  0.301479 -0.010601  0.229374
# 4  -0.179950  0.052226  0.301479 -0.249254  0.025367
# ..       ...       ...       ...       ...       ...
# 95 -0.146648  0.016740  0.301479 -0.284740  0.025367
# 96  0.083656 -0.059327  0.301479 -0.360807  0.025367
# 97 -0.422265  0.545097  0.301479  0.243618  0.562124
# 98  0.474395  0.637334  0.301479  0.335854  0.660267
# 99  0.486211  0.638090  0.301479  0.336611  0.660267
#
# [100 rows x 5 columns]

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.scatter(df["X"],df["pred2"],linewidth=2,color="red")
plt.scatter(df["X"],df["y"])

# %%
df["res2"]=df["y"]-df["pred2"]

# %%
df
# Out:
#            X         y     pred1      res1     pred2      res2
# 0  -0.396876  0.489620  0.301479  0.188140  0.457603  0.032016
# 1   0.402553  0.579955  0.301479  0.278476  0.477543  0.102412
# 2   0.005252  0.047604  0.301479 -0.253875  0.025367  0.022237
# 3   0.326457  0.290878  0.301479 -0.010601  0.229374  0.061504
# 4  -0.179950  0.052226  0.301479 -0.249254  0.025367  0.026859
# ..       ...       ...       ...       ...       ...       ...
# 95 -0.146648  0.016740  0.301479 -0.284740  0.025367 -0.008627
# 96  0.083656 -0.059327  0.301479 -0.360807  0.025367 -0.084694
# 97 -0.422265  0.545097  0.301479  0.243618  0.562124 -0.017027
# 98  0.474395  0.637334  0.301479  0.335854  0.660267 -0.022934
# 99  0.486211  0.638090  0.301479  0.336611  0.660267 -0.022177
#
# [100 rows x 6 columns]

# %%
tree2=DecisionTreeRegressor(max_leaf_nodes=8)
tree2.fit(df["X"].values.reshape(100,1),df["res2"].values)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=8)

# %%
y_pred = 0.301479+sum(regressor.predict(X_test.reshape(-1,1)) for regressor in [tree1,tree2])

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.plot(X_test,y_pred,linewidth=2,color="red")
plt.scatter(df["X"],df["y"])
